# %%
import pandas as pd

# %%
df=pd.read_csv(r"C:\Users\aqdas\Downloads\archive\salesdaily.csv")

# %%
#checking files
df.head(10)
# Out:
#        datum  M01AB  M01AE  N02BA  N02BE  N05B  N05C   R03  R06  Year  Month  \
# 0   1/2/2014   0.00   3.67    3.4  32.40   7.0   0.0   0.0  2.0  2014      1
# 1   1/3/2014   8.00   4.00    4.4  50.60  16.0   0.0  20.0  4.0  2014      1
# 2   1/4/2014   2.00   1.00    6.5  61.85  10.0   0.0   9.0  1.0  2014      1
# 3   1/5/2014   4.00   3.00    7.0  41.10   8.0   0.0   3.0  0.0  2014      1
# 4   1/6/2014   5.00   1.00    4.5  21.70  16.0   2.0   6.0  2.0  2014      1
# 5   1/7/2014   0.00   0.00    0.0   0.00   0.0   0.0   0.0  0.0  2014      1
# 6   1/8/2014   5.33   3.00   10.5  26.40  19.0   1.0  10.0  0.0  2014      1
# 7   1/9/2014   7.00   1.68    8.0  25.00  16.0   0.0   3.0  2.0  2014      1
# 8  1/10/2014   5.00   2.00    2.0  53.30  15.0   2.0   0.0  2.0  2014      1
# 9  1/11/2014   5.00   4.34   10.4  52.30  14.0   0.0   1.0  0.2  2014      1
#
#    Hour Weekday Name
# 0   248     Thursday
# 1   276       Friday
# 2   276     Saturday
# 3   276       Sunday
# ...

# %%
df.shape
# Out:
# (2106, 13)

# %%
df.columns
# Out:
# Index(['datum', 'M01AB', 'M01AE', 'N02BA', 'N02BE', 'N05B', 'N05C', 'R03',
#        'R06', 'Year', 'Month', 'Hour', 'Weekday Name'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2106 entries, 0 to 2105
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   datum         2106 non-null   object
#  1   M01AB         2106 non-null   float64
#  2   M01AE         2106 non-null   float64
#  3   N02BA         2106 non-null   float64
#  4   N02BE         2106 non-null   float64
#  5   N05B          2106 non-null   float64
#  6   N05C          2106 non-null   float64
#  7   R03           2106 non-null   float64
#  8   R06           2106 non-null   float64
#  9   Year          2106 non-null   int64
#  10  Month         2106 non-null   int64
#  11  Hour          2106 non-null   int64
#  12  Weekday Name  2106 non-null   object
# dtypes: float64(8), int64(3), object(2)
# memory usage: 214.0+ KB

# %%
#overall summary
df.describe()
# Out:
#              M01AB        M01AE        N02BA        N02BE         N05B  \
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000
# mean      5.033683     3.895830     3.880441    29.917095     8.853627
# std       2.737579     2.133337     2.384010    15.590966     5.605605
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     2.340000     2.000000    19.000000     5.000000
# 50%       4.990000     3.670000     3.500000    26.900000     8.000000
# 75%       6.670000     5.138000     5.200000    38.300000    12.000000
# max      17.340000    14.463000    16.000000   161.000000    54.833333
#
#               N05C          R03          R06         Year        Month  \
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000
# mean      0.593522     5.512262     2.900198  2016.401235     6.344255
# std       1.092988     6.428736     2.415816     1.665060     3.386954
# ...

# %%
#checking for any null value
df.isnull().sum()
# Out:
# datum           0
# M01AB           0
# M01AE           0
# N02BA           0
# N02BE           0
# N05B            0
# N05C            0
# R03             0
# R06             0
# Year            0
# Month           0
# Hour            0
# Weekday Name    0
# dtype: int64

# %%
#looking for weekday patern,which day appear more,data balance across week
df['Weekday Name'].value_counts()
# Out:
# Weekday Name
# Thursday     301
# Friday       301
# Saturday     301
# Sunday       301
# Monday       301
# Tuesday      301
# Wednesday    300
# Name: count, dtype: int64

# %%
#checking one column
df['M01AB'].describe()
# Out:
# count    2106.000000
# mean        5.033683
# std         2.737579
# min         0.000000
# 25%         3.000000
# 50%         4.990000
# 75%         6.670000
# max        17.340000
# Name: M01AB, dtype: float64

# %%
#data cleaning ,converting date column format object to date format
df['datum']=pd.to_datetime(df['datum'])

# %%
df.dtypes
# Out:
# datum           datetime64[ns]
# M01AB                  float64
# M01AE                  float64
# N02BA                  float64
# N02BE                  float64
# N05B                   float64
# N05C                   float64
# R03                    float64
# R06                    float64
# Year                     int64
# Month                    int64
# Hour                     int64
# Weekday Name            object
# dtype: object

# %%
#sorting the date to acsending order 
df=df.sort_values('datum')

# %%
df['datum']
# Out:
# 0      2014-01-02
# 1      2014-01-03
# 2      2014-01-04
# 3      2014-01-05
# 4      2014-01-06
#           ...
# 2101   2019-10-04
# 2102   2019-10-05
# 2103   2019-10-06
# 2104   2019-10-07
# 2105   2019-10-08
# Name: datum, Length: 2106, dtype: datetime64[ns]

# %%
#saving cleaned salesdaily files
df.to_csv("salesdaily_clean.csv", index=False)
